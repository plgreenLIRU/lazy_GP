# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from lazy_GP import Lazy_GP

# %% [markdown]
# Generate 1D regression problem

# %%
np.random.seed(42)  # for reproducibility
sigma = 0.05
X = np.linspace(0, 10, 50)[:, np.newaxis]
X_star = np.linspace(0, 10, 100)[:, np.newaxis]
y = np.sin(X[:, 0]) + sigma * np.random.randn(len(X))
y_star = np.sin(X_star[:, 0]) + sigma * np.random.randn(len(X_star))

# %% [markdown]
# Fit GP

# %%
m = Lazy_GP()
m.set_hyperparameters(X=X, y=y, theta=1, sigma=0.1)
y_star_pred = m.predict(X_star)
# Out:
# CG converged in 20 iterations.

# %% [markdown]
# Results

# %%
mse = mean_squared_error(y_star, y_star_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.002690069735448658

# %%
fig, ax = plt.subplots()
ax.plot(X, y, 'o', label='Data')
ax.plot(X_star, y_star_pred, '-', label='Prediction')
ax.legend()
ax.grid()
plt.show()
